# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split

# %%
X, _ = make_blobs(n_samples=300, centers=3, random_state=4) # _ = place holder. To receive anything we want.

X
# Out:
# array([[ 2.80492765, -5.49685296],
#        [ 8.14714853,  3.98544896],
#        [11.42240659,  5.9692263 ],
#        [10.71519001,  0.49360207],
#        [ 9.16948179,  1.12892974],
#        [10.46723726,  4.75590165],
#        [ 3.89455221, -5.32062985],
#        [ 9.63773799, -0.01713182],
#        [10.01439827,  1.97109995],
#        [ 9.90801006,  3.88184611],
#        [ 4.78163984, -5.20296428],
#        [ 2.29191631, -6.70075161],
#        [ 6.96082151,  0.33696129],
#        [10.72156491, -1.02710809],
#        [ 8.68937095,  1.48709629],
#        [12.15865063,  4.38637393],
#        [ 5.55249939, -5.47348159],
#        [ 9.05329421,  4.94563435],
#        [ 3.04883721, -5.97378483],
#        [ 9.37923199,  0.46379584],
#        [ 3.19453583, -5.53228002],
#        [ 9.26368536,  6.04176438],
#        [ 9.58820432,  6.16588539],
#        [ 2.95060298, -5.01222065],
#        [ 9.19714932,  4.46168032],
#        [ 3.01347506, -5.90302848],
#        [ 4.33685754, -5.27351671],
# ...

# %%
df_train = pd.DataFrame(data=X, columns=['X1', 'X2'])
df_train
# Out:
#             X1        X2
# 0     2.804928 -5.496853
# 1     8.147149  3.985449
# 2    11.422407  5.969226
# 3    10.715190  0.493602
# 4     9.169482  1.128930
# ..         ...       ...
# 295   7.993136  0.935285
# 296  11.456333  0.703386
# 297  10.741874  2.500583
# 298  10.801116  5.696481
# 299  10.569810  2.544522
#
# [300 rows x 2 columns]

# %%
df_train.describe().T
# Out:
#     count      mean       std       min       25%       50%       75%  \
# X1  300.0  7.702730  2.741472  2.267297  4.735711  8.837666  9.709900
# X2  300.0 -0.087257  4.295794 -7.542041 -4.897481  0.972154  3.873398
#
#           max
# X1  12.230822
# X2   7.083123

# %%
model = KMeans(n_clusters=3, random_state=2143)

model.fit(X)

new_data = np.array([[2, 3], [0, 4], [3, 1]])

prediction = model.predict(new_data)
# Out:
# /workspaces/K_means_algorithm/.venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
prediction_all = model.predict(X)
prediction_all
# Out:
# array([0, 1, 1, 2, 2, 1, 0, 2, 2, 1, 0, 0, 2, 2, 2, 1, 0, 1, 0, 2, 0, 1,
#        1, 0, 1, 0, 0, 1, 2, 2, 0, 2, 1, 0, 2, 0, 2, 0, 1, 2, 0, 1, 1, 0,
#        0, 1, 0, 2, 2, 2, 2, 2, 1, 1, 2, 2, 1, 0, 0, 1, 1, 1, 1, 0, 1, 0,
#        2, 1, 0, 1, 1, 0, 2, 0, 2, 0, 0, 2, 0, 0, 2, 2, 2, 1, 0, 2, 0, 1,
#        2, 2, 2, 1, 0, 1, 1, 0, 1, 2, 0, 1, 1, 0, 2, 2, 1, 2, 1, 0, 2, 0,
#        2, 1, 1, 1, 1, 1, 0, 2, 0, 2, 0, 2, 1, 2, 2, 1, 2, 2, 1, 0, 2, 1,
#        0, 1, 2, 2, 1, 2, 1, 0, 1, 0, 0, 0, 1, 0, 1, 0, 2, 0, 1, 1, 2, 0,
#        1, 1, 2, 1, 2, 0, 2, 0, 1, 1, 0, 0, 0, 2, 1, 2, 0, 1, 1, 2, 2, 0,
#        1, 0, 0, 0, 0, 1, 1, 0, 2, 1, 0, 1, 2, 0, 1, 0, 0, 2, 2, 0, 0, 1,
#        2, 1, 2, 1, 2, 0, 1, 0, 2, 2, 0, 2, 2, 2, 1, 2, 2, 2, 1, 1, 2, 2,
#        2, 0, 1, 2, 1, 2, 1, 0, 0, 0, 2, 2, 1, 0, 0, 2, 0, 0, 0, 1, 2, 2,
#        1, 2, 0, 0, 1, 2, 1, 0, 2, 0, 0, 2, 0, 2, 1, 2, 2, 1, 0, 0, 2, 0,
#        0, 0, 0, 1, 0, 1, 0, 1, 2, 2, 0, 0, 1, 2, 2, 0, 1, 1, 1, 2, 2, 0,
# ...

# %%
df_train['cluster'] = prediction_all
df_train
# Out:
#             X1        X2  cluster
# 0     2.804928 -5.496853        0
# 1     8.147149  3.985449        1
# 2    11.422407  5.969226        1
# 3    10.715190  0.493602        2
# 4     9.169482  1.128930        2
# ..         ...       ...      ...
# 295   7.993136  0.935285        2
# 296  11.456333  0.703386        2
# 297  10.741874  2.500583        2
# 298  10.801116  5.696481        1
# 299  10.569810  2.544522        2
#
# [300 rows x 3 columns]

# %%
sns.pairplot(data=df_train, hue='cluster')
plt.show()
# Out:
# /workspaces/K_means_algorithm/.venv/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
X, y = load_iris(return_X_y=True, as_frame=True)

X_train, X_test, y_test, y_train = train_test_split(X, y, random_state=45, test_size=0.2)

df_iris = X_train.copy()

df_iris['specie'] = y_train.copy()

# %%
df_iris.corr()
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.071742           0.861400
# sepal width (cm)           -0.071742          1.000000          -0.404272
# petal length (cm)           0.861400         -0.404272           1.000000
# petal width (cm)            0.811524         -0.336375           0.964251
# specie                           NaN               NaN                NaN
#
#                    petal width (cm)  specie
# sepal length (cm)          0.811524     NaN
# sepal width (cm)          -0.336375     NaN
# petal length (cm)          0.964251     NaN
# petal width (cm)           1.000000     NaN
# specie                          NaN     NaN

# %%
pca = PCA(n_components=2)

X_pca = pca.fit_transform(X_train)

X_pca
# Out:
# array([[ 1.32531401,  0.23923029],
#        [ 0.36906688, -0.28436012],
#        [ 1.29230548, -0.76265476],
#        [ 1.4079287 , -0.56269464],
#        [-2.51378012, -0.1379075 ],
#        [ 1.89861568,  0.05646542],
#        [-3.23127318, -0.49530363],
#        [-2.47494962,  0.14655231],
#        [ 0.70821689,  0.14941103],
#        [-2.59449336, -0.19272511],
#        [-2.60310013,  1.1093315 ],
#        [ 0.12908197, -0.30936771],
#        [-2.72119629, -0.16722412],
#        [ 1.45827869,  0.50249814],
#        [-0.71310619, -1.00417188],
#        [-2.54913367,  0.4510329 ],
#        [ 1.79645403, -0.21098352],
#        [ 0.25656187, -0.55659104],
#        [ 3.48259607,  1.17849687],
#        [-2.8067681 ,  0.28366746],
#        [-2.72146373, -0.23775349],
#        [ 0.65327576, -0.33954318],
#        [ 2.11688474, -0.20168768],
#        [-2.54859878,  0.59209163],
#        [ 2.41361712,  0.32066693],
#        [-2.59335763,  0.53122355],
#        [-2.63898477, -0.18306382],
# ...
